# %% [markdown]
# **Semana 1. Clase 1. 19/01/2026**

# %% [markdown]
# Tipo de datos:
# Hay 4 tipos de dator principales primitivos:
# los tipos de variables.
#
# *enteros (int) en Python, son datos sin decimal (1, 2, 3, 4)
#
# *Flotantes (float) son los que tienen decimal (12.4, 13.67)
#
# *cadena (string) son datos que forman alguna oración como: (casa, árbol, niño, niña), siempre van a ir en comillas o apostrofe
#
# *booleano (bool) son datos que solo pueden tomar valores de verdadero o falso, generalmente verdadero es 1, falso es 0.

# %%
a = 3 #Dato tipo int
b = 4.5 #Dato tipo float
c = 'alumno'#Dato tipo string siempre en comillas
d = False #Dato tipo booleano

a = 0
if a < 1:
print 'good job'
# Out:
#   File "/tmp/ipython-input-3967282262.py", line 8
#     print 'good job'
#     ^
# IndentationError: expected an indented block after 'if' statement on line 7
